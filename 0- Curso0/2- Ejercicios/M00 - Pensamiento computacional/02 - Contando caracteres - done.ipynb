# %% [markdown]
# # Contando caracteres
#
# El programa pedirá una cadena de caracteres y devolverá el número de caracteres.
#
# ## Restricciones
# 1. Asegurate de que devuelve la cadena original
# 2. Utiliza la función específica de python para resolverlo

# %%
palabra = input ("Dime una palabra y te diré cuántas letras tiene. ")
print ("\""+palabra+"\" tiene", len(palabra), "caracteres")
# Out:
# Dime una palabra y te diré cuántas letras tiene. que no
# "que no" tiene 6 caracteres

# %% [markdown]
# ## Retos
#
# 1. Si el usuario no introduce nada, el programa le conminará a que escriba algo.

# %%
palabra = input ("Dime una palabra y te diré cuántas letras tiene. ")
while palabra == "":
  palabra = input("Perdona, para continuar necesito que me digas una palabra. ") 
print ("\""+palabra+"\" tiene", len(palabra), "caracteres")
# Out:
# Dime una palabra y te diré cuántas letras tiene. no quiero
# "no quiero" tiene 9 caracteres

# %% [markdown]
# 2. Hazlo sin utilizar la función específica de python

# %%
palabra = input ("Dime una palabra y te diré cuántas letras tiene. ")
while palabra == "":
  palabra = input("Perdona, para continuar necesito que me digas una palabra. ") 
i=0
for letra in palabra: 
  i += 1

print ("\""+palabra+"\" tiene", i, "caracteres")
# Out:
# Dime una palabra y te diré cuántas letras tiene. ornitorrinco
# "ornitorrinco" tiene 12 caracteres
