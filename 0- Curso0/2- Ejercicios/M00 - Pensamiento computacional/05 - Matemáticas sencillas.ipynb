# %% [markdown]
# # Operaciones aritméticas
#
# Escribe un programa que pida dos números y que devuelva su suma, resta, producto y división.
#
# ## Restricciones
#
# 1. Convertir las cadenas de entrada en números
# 2. Separar convenientemente la entrada, transformación de cadena en números y salida separados
# 3. Crea una única sentencia de salida con los saltos de línea adecuados (sólo un print)

# %% [markdown]
# ## Retos
#
# 1. Controla que las entradas sean números de forma que el programa no avance si no se introduce un número
# 2. No permitas introducir números negativos

# %%
a = input("Dime un número ")

while type(a) != int: 
  try: 
    a = int(a)
  except:
    a=input("Disculpa, me falta un número ")

b = input("Dime otro número ")

while type(b) != int:
  try: 
    b=int(b)
  except:
    b=input("Disculpa, me falta un número ")

print("La suma es: {} \t La resta es: {} \t El producto es: {} \t La división es: {} \t".format(a+b, a-b, a*b, a/b))
# Out:
# Dime un número a
# Disculpa, me falta un número 1
# Dime otro número 2
# La suma es: 3 	 La resta es: -1 	 El producto es: 2 	 La división es: 0.5

# %%
i=0
n=[]

while i<2: 
  answer = input("Dime un número: ")

  try: 
    n.append(float(answer))
    i += 1
  except:
    print("No sé hacer operaciones matemáticas con letras ni signos.")

if n[1] == 0:
  print("Ojo, que no sé hacer divisiones entre 0")
  print("La suma es: {} \t La resta es: {} \t El producto es: {} \t La división es: ¡inifinita! \t".format(sum(n), n[0]-n[1], n[0]*n[1]))

else:
  print("La suma es: {} \t La resta es: {} \t El producto es: {} \t La división es: {} \t".format(sum(n), n[0]-n[1], n[0]*n[1], n[0]/n[1]))
# Out:
# Dime un número: 3
# Dime un número: '
# No sé hacer operaciones matemáticas con letras ni signos.
# Dime un número: 0
# Ojo, que no sé hacer divisiones entre 0
# La suma es: 3.0 	 La resta es: 3.0 	 El producto es: 0.0 	 La división es: ¡inifinita!
