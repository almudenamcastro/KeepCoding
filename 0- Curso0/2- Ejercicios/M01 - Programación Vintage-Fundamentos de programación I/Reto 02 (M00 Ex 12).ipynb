# %% [markdown]
# # Cálculo de interés simple con funciones
#
# Crear una función *CalculateSimpleInterest(Amount, tax, years)* que devuelva el valor de la inversión transcurrido el tiempo indicado.
#
# Crearla como módulo y modicar el[ ejercicio 12 del módulo 00](https://colab.research.google.com/drive/1XG4WB5oaK4VTP9Rs4l6pbilZCSwQSepr#scrollTo=ai4j58d6AzJw&line=15&uniqifier=1) para usar la función primero y el módulo después

# %%
def CalculateSI(amount, tax, years): 
  return amount*(1 + tax)**years

# %%
CalculateSI(100, 0.05, 10)
# Out:
# 162.8894626777442
