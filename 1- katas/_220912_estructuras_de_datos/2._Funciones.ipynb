# %% [markdown]
# # Funciones

# %% [markdown]
# ```
# def funcion (parametros):
#     bloque de codigo
# ```

# %% [markdown]
# ## Parámetros de una función

# %%
def potenciacion(base, exponente):
    return base ** exponente

# %%
potenciacion(2, 5)
# Out:
# 32

# %%
potenciacion(5, 2)
# Out:
# 25

# %%
potenciacion(base = 3, exponente = 5)
# Out:
# 243

# %%
potenciacion(exponente = 5, base = 3)
# Out:
# 243

# %% [markdown]
# ## Parámetros con valores por defecto

# %%
def potenciacion(base, exponente = 2):
    return base ** exponente

# %%
potenciacion(5, 3)
# Out:
# 125

# %%
potenciacion(5)
# Out:
# 25

# %% [markdown]
# ## Funciones lambda

# %%
def potenciacion(base, exponente):
    return base ** exponente

# %%
potenciacion_lambda = lambda base, exponente: base ** exponente

# %%
potenciacion_lambda(3, 4)
# Out:
# 81

# %% [markdown]
# ## Comentarios en funciones

# %% [markdown]
# Ojo: el texto entre triples comillas es accesible mediante la función help, ej: help (potenciacion)

# %%
def potenciacion(base, exponente):
    """
    funcion que calcula la potenciacion de una base a un exponente

    params:

    base: int
    exponente: int
    """

    return base ** exponente

# %%
potenciacion(3, 5)
# Out:
# 243

# %%
help(potenciacion)
# Out:
# Help on function potenciacion in module __main__:
#
# potenciacion(base, exponente)
#     funcion que calcula la potenciacion de una base a un exponente
#
#     params:
#
#     base: int
#     exponente: int

# %%
suma = lambda a, b: a+b

# %%
suma(1,7)
# Out:
# 8
